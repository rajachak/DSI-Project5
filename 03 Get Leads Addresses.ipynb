# %%
import keys
import numpy as np
import pandas as pd
import json
import urllib
import requests
import re
import matplotlib.pyplot as plt
import requests
from pandas.io.json import json_normalize
from bs4 import BeautifulSoup
import requests
from pprint import pprint
import json
# %matplotlib inline

# %%
#df2 = pd.read_csv('leads.csv')

# %%
lead['lat']=np.nan
lead['lng']=np.nan

# %%
df2['address'] = df2['Street']+ ' '+ df2['City'] +' '+ df2['State/Province'] +' '+ df2['Zip/Postal Code'] #+' '+ df2['Country']

# %%
df2[(df2['lat'].isnull()==True) &
                  (df2['address'].isnull()==False) &
                  (df2['Zip/Postal Code'].isnull()==False)
                 ].head()
# Out:
#     Unnamed: 0          Lead ID    First Name     Last Name Lead Source  \
# 5            5  00Q1a00000C2kjc         Craig       Shannon         NaN
# 6            6  00Q1a00000C2kjD  Craig Nisbet  Craig Nisbet         NaN
# 31          31  00Q1a0000044Iol          Sean         Foley         NaN
# 43          43  00Q1a00000C15e8          John        Aggrey         NaN
# 60          60  00Q1a00000LHjdi          Andy          Clay         NaN
#
#    Lead Status                        Street           City  \
# 5    Contacted               500 Kipling Ave       Montreal
# 6    Contacted  243 Consumers Rd Phoebe Cres     North York
# 31   Contacted             5255 Yonge Street        Toronto
# 43   Contacted       1250 Connecticut Ave NW  Mountain View
# 60   Contacted           2415 E Camelback Rd         Denver
#
#           State/Province Zip/Postal Code        Country  lat  lng  \
# 5                 Quebec         M8Z 5E5         Canada  NaN  NaN
# 6                Ontario         M2J 4W8         Canada  NaN  NaN
# 31      British Columbia         M2N 6P4         Canada  NaN  NaN
# 43  District of Columbia           94043  United States  NaN  NaN
# 60               Arizona      85016-4288  United States  NaN  NaN
#
#                                               address
# 5      500 Kipling Ave Canada Montreal Quebec M8Z 5E5
# 6   243 Consumers Rd Phoebe Cres Canada North York...
# 31  5255 Yonge Street Canada Toronto British Colum...
# 43  1250 Connecticut Ave NW United States Mountain...
# 60  2415 E Camelback Rd United States Denver Arizo...

# %%
#key = 'xxx'
key = keys.google
counter = 0
for i, row in df2[(df2['lat'].isnull()==True) &
                  (df2['address'].isnull()==False) &
                  (df2['Zip/Postal Code'].isnull()==False)
                 ].iterrows():
    address = row.address.replace(' ','+')
    url = 'https://maps.googleapis.com/maps/api/geocode/json?address='+address+'=&key='+key
    #print(url)
    #print(row.address)
    response = requests.get(url)
    try:
        data = json.loads(response.text)
        lat = data['results'][0]['geometry']['location']['lat']
        lng = data['results'][0]['geometry']['location']['lng']
        df2.loc[df2['Lead ID'] == row['Lead ID'], 'lat'] = lat
        df2.loc[df2['Lead ID'] == row['Lead ID'], 'lng'] = lng
    except:
        #print ('request failure for row', i, row['Unnamed: 0'], data, url)
        pass
    counter +=1
    if counter%500==0:
         print(counter,address,lat,lng)
    if counter%500 == 0:
        df2.to_csv('lead geocoded.csv', index=False) 
        #break
# Out:
# 500 6406+Ivy+Ln+Ste+700+DC/Bmore+Maryland+20770-1441 41.8847775 -87.6306113
# 1000 1200,+585+-+8th+Avenue+SW,+Eighth+Avenue+Place+-+West+Calgary+Alberta+T2P+3C5 51.0456561 -114.0727114
# 1500 8900+Keystone+Xing+Ste+1150+Indianapolis,+IN+Indiana+46240-7667 39.9171029 -86.11116040000002
# 2000 1+City+Hall+Sq+Boston,+MA+02201+Massachusetts+02201-1001 42.3602752 -71.0579295
# 2500 11690+Grooms+Rd+Cincinnati+Ohio+45242-1412 39.28193690000001 -84.3675913
# 3000 174+W+Comstock+Ave+Ste+111+Orlando+Florida+32789-4347 28.5939405 -81.3519298
# 3500 4+Park+Plz+Ste+700+Newport+Beach+California+92614-2554 33.6782718 -117.8372172
# 4000 1122+N+La+Salle+Dr+Chicago+Illinois+60610-2602 41.9027435 -87.6332523
# 4500 355+Lexington+Ave+Fl+11+New+York+New+York+10017-6603 40.7502126 -73.97646019999999
# 5000 210+Gladstone+Ave+Ottawa+Ontario+K2P+0Y6 45.4141066 -75.68847319999999
# 5500 1455+East+Putnam+Ave.+2nd+Fl.+Old+Greenwich+Connecticut+06870 41.0463178 -73.57142379999999
# 6000 2345+Grand+Blvd+Ste+700+Kansas+City+Missouri+64108-2625 39.084917 -94.581113
# 6500 299+Park+Ave+New+York+New+York+10171-0002 40.756039 -73.9741415
# 7000 6100+Fairview+Rd.+Ste.+355+Charlotte+North+Carolina+28210 35.149998 -80.8375552

# %%
df2.to_csv('lead geocoded.csv', index=False)

# %%
print (df2[df2.lat.isnull()==True].shape)
print (df2[df2.lat.isnull()==False].shape)
# Out:
# (6315, 13)
# (10745, 13)

# %%
lead.to_csv('lead geocoded.csv')

# %%
lead[(lead['lat'].isnull()) & (lead['lng'].isnull())].shape
# Out:
# (12883, 13)

# %%
lead[lead['lat'].isnull()==False].shape
# Out:
# (4180, 13)

# %%
df2 = pd.read_csv('lead geocoded.csv')

# %%
df2.head(100)
# Out:
#     Unnamed: 0          Lead ID    First Name     Last Name  \
# 0            0  00Q1a00000Lqb3V        Audrey       McStraw
# 1            1  00Q1a00000Lqb3W        Roscoe         Chubb
# 2            2  00Q1a00000Lqb3X        Robert         Grant
# 3            3  00Q1a00000LHtQ2          Paul         Dutko
# 4            4  00Q1a00000I1an7        Dermot        Sweeny
# 5            5  00Q1a00000C2kjc         Craig       Shannon
# 6            6  00Q1a00000C2kjD  Craig Nisbet  Craig Nisbet
# 7            7  00Q1a00000C2kjw        Galeeb         Mehdi
# 8            8  00Q1a000003P8dX         Erica          Yoon
# 9            9  00Q1a000003Ozwb        Nelson        Garcia
# 10          10  00Q1a0000042TVv           Pru         Ashby
# 11          11  00Q1a0000042TWU        Padric       Gleason
# 12          12  00Q1a00000INi3k       Michael      Randolph
# 13          13  00Q1a000001vP0g       Obadiah     Greenberg
# 14          14  00Q1a000001vP0k         K_ren         Haley
# 15          15  00Q1a000001vP0l         Luann      Hamilton
# 16          16  00Q1a000001vP0m         Steve       Harding
# 17          17  00Q1a000001vP0n        Robert          Haun
# 18          18  00Q1a000008Feh2          Teri         Smith
# 19          19  00Q1a000001vP0p         Frank       Hebbert
# 20          20  00Q1a000001vP0v        Philip            Ho
# 21          21  00Q1a000001vP0x         Robin     Hutcheson
# 22          22  00Q1a000001vP10           Rob       Johnson
# 23          23  00Q1a000001vP1J         Trent        Lethco
# 24          24  00Q1a000001vP18          John       Kennedy
# 25          25  00Q1a000001vP1A        Kurtis    Kingsolver
# 26          26  00Q1a000001vP1F            Si           Lau
# 27          27  00Q1a000001vP1G           Dan        Layden
# 28          28  00Q1a000003P8Dc       Lorenzo         Parra
# 29          29  00Q1a00000GWPdJ        Sandra      Alcantar
# ..         ...              ...           ...           ...
# 70          70  00Q1a00000PTTaj          Mike        Greene
# 71          71  00Q1a00000PTTao         Steve          Toth
# 72          72  00Q1a00000PTTar          Tony     Skillbeck
# 73          73  00Q1a00000PTTau         James       Borders
# 74          74  00Q1a00000PTTav          Mark      Brambrut
# 75          75  00Q1a00000PTTaw          Mark       Dressel
# 76          76  00Q1a00000PTTay        George         Jones
# 77          77  00Q1a00000PTTaz         Kevin      McDaniel
# 78          78  00Q1a00000cb7ke          Carl      Goldberg
# 79          79  00Q1a00000cakrX       Richard        Turner
# 80          80  00Q1a00000cajd8         Scott    Glosserman
# 81          81  00Q1a00000PQYRr          Katy       Malecha
# 82          82  00Q1a00000PQYRt         Holly        Nathan
# 83          83  00Q1a00000PQYRu       Rebekah       Rollins
# 84          84  00Q1a00000PQYRw        Andrew        Siegel
# 85          85  00Q1a00000PQYRx         Mindy        Tucker
# 86          86  00Q1a00000PTTb0         Frank         Reese
# 87          87  00Q1a00000PQYbM        Leslie           Bos
# 88          88  00Q1a00000PQYbO       Teronda         Ellis
# 89          89  00Q1a00000PQYbP       Michael        Gondek
# 90          90  00Q1a00000PQYbT          Lisa          King
# 91          91  00Q1a00000PTTb2      Gardiner      Thompson
# 92          92  00Q1a00000PTTb4        Janice      Williams
# 93          93  00Q1a00000PTTb3          Andy         Vance
# 94          94  00Q1a00000kY6Vc         Shawn       Cardner
# 95          95  00Q1a00000SekZ5         Peter       DiLullo
# 96          96  00Q1a00000PTTbz         David       Edwards
# 97          97  00Q1a00000PTTc3           Dan        Fields
# 98          98  00Q1a00000PTTc5         James       Fleming
# 99          99  00Q1a00000PTTc6         Chuck       Francis
#
#           Lead Source  Lead Status  \
# 0                 NaN    Contacted
# 1                 NaN    Contacted
# 2                 NaN    Contacted
# 3                 NaN    Contacted
# 4                 NaN    Contacted
# 5                 NaN    Contacted
# 6                 NaN    Contacted
# 7                 NaN    Contacted
# 8                 NaN    Contacted
# 9   External Referral         Open
# 10                NaN    Contacted
# 11  Seminar - Partner    Contacted
# 12                NaN    Contacted
# 13          MailChimp         Open
# 14          MailChimp         Open
# 15          MailChimp         Open
# 16          MailChimp         Open
# 17          MailChimp         Open
# 18                NaN    Contacted
# 19          MailChimp         Open
# 20          MailChimp         Open
# 21          MailChimp         Open
# 22          MailChimp         Open
# 23          MailChimp         Open
# 24          MailChimp         Open
# 25          MailChimp         Open
# 26          MailChimp         Open
# 27          MailChimp         Open
# 28                NaN         Open
# 29                NaN         Open
# ..                ...          ...
# 70                NaN    Contacted
# 71                NaN  Unqualified
# 72                NaN  Unqualified
# 73                NaN    Contacted
# 74                NaN    Contacted
# 75                NaN    Contacted
# 76                NaN    Contacted
# 77                NaN    Contacted
# 78                NaN    Contacted
# 79  External Referral    Contacted
# 80                NaN         Open
# 81                NaN    Contacted
# 82                NaN    Contacted
# 83                NaN    Contacted
# 84                NaN    Contacted
# 85                NaN    Contacted
# 86                NaN    Contacted
# 87                NaN    Contacted
# 88        BD Outreach    Contacted
# 89                NaN  Unqualified
# 90        BD Outreach    Contacted
# 91                NaN    Contacted
# 92                NaN  Unqualified
# 93                NaN    Contacted
# 94  Seminar - Partner    Contacted
# 95                NaN    Contacted
# 96                NaN    Contacted
# 97                NaN  Unqualified
# 98                NaN  Unqualified
# 99        BD Outreach    Contacted
#
#                                             Street                   City  \
# 0                                        1st Floor  Belfast County Antrim
# 1                      Embassy House Queens Avenue           Bristol Avon
# 2                      Wemyss House 8 Wemyss Place   Edinburgh Midlothian
# 3                         8601 Georgia Ave Ste 200          Silver Spring
# 4                              468 Wellington St W                Toronto
# 5                                  500 Kipling Ave               Montreal
# 6                     243 Consumers Rd Phoebe Cres             North York
# 7                                  500 Kipling Ave              Etobicoke
# 8                              661 University Ave.                Toronto
# 9                                   8652 Dakota Dr           Gaithersburg
# 10                            845 3rd Ave. 9th Fl.               New York
# 11                            845 3rd Ave. 9th Fl.               New York
# 12                                62 Summer Street                 Boston
# 13          1600 Amphitheatre Pkwy Google Ventures          Mountain View
# 14                                132 W Walnut St.           Indianapolis
# 15                       121 N La Salle St Rm 1104                Chicago
# 16                       701 5th Avenue Suite 6550                Seattle
# 17                           2263 Santa Clara Ave.                Alameda
# 18  412-1155 Robson Street, Vancouver, BC, V6E 1B5              Vancouver
# 19                          148 Lafayette St Fl 12               New York
# 20                  250 Frank H Ogawa Plz Ste 4314                Oakland
# 21                                     110 E 900 S         Salt Lake City
# 22                                     20 Jones St           New Rochelle
# 23                           901 Market St Ste 260          San Francisco
# 24                                     PO BOX 9151                 Boston
# 25                                   747 Market St                 Tacoma
# 26                             1 Frank H Ogawa Plz                Oakland
# 27                      111 SW Columbia St Ste 600               Portland
# 28                            10 Park Plz Ste 4160                 Boston
# 29                                    3951 Park Dr               Carlsbad
# ..                                             ...                    ...
# 70                   817 W Peachtree St NW Ste 400                Atlanta
# 71                   817 W Peachtree St NW Ste 400                Atlanta
# 72                   817 W Peachtree St NW Ste 400                Atlanta
# 73                  817 W Peachtree St NW Ste a135                Atlanta
# 74                  817 W Peachtree St NW Ste a135                Atlanta
# 75                   817 W Peachtree St NW Ste 400                Atlanta
# 76                   817 W Peachtree St NW Ste 400                Atlanta
# 77                   817 W Peachtree St NW Ste 601                Atlanta
# 78                 75 Eisenhower Parkway Suite 180               Roseland
# 79                      3100 Massachusetts Ave. NW             Washington
# 80                    7919 Sunset Blvd Los Angeles              CA. 90046
# 81                        2 Overhill Rd, Suite 425    Scarsdale, NY 10583
# 82                        2 Overhill Rd, Suite 425    Scarsdale, NY 10583
# 83                        2 Overhill Rd, Suite 425    Scarsdale, NY 10583
# 84                        2 Overhill Rd, Suite 425    Scarsdale, NY 10583
# 85                        2 Overhill Rd, Suite 425    Scarsdale, NY 10583
# 86                   817 W Peachtree St NW Ste 400                Atlanta
# 87                                  30 Germania St          Jamaica Plain
# 88                                  31 Germania St          Jamaica Plain
# 89                                  31 Germania St          Jamaica Plain
# 90                                  30 Germania St          Jamaica Plain
# 91                   817 W Peachtree St NW Ste 400                Atlanta
# 92                  817 W Peachtree St NW Ste a135                Atlanta
# 93                   817 W Peachtree St NW Ste 400                Atlanta
# 94                          4601 Park Rd. Ste. 450              Charlotte
# 95                                 850 Cassatt Rd.                 Berwyn
# 96                                191 Peachtree St                Atlanta
# 97                    191 Peachtree St NE Ste 3600                Atlanta
# 98               2500 Windy Ridge Pkwy SE Ste 1600                Atlanta
# 99                    191 Peachtree St NE Ste 3600                Atlanta
#
#           State/Province Zip/Postal Code        Country        lat  \
# 0                    NaN             NaN  United States        NaN
# 1                    NaN             NaN  United States        NaN
# 2                    NaN             NaN  United States        NaN
# 3               Maryland      20910-3438  United States  38.996533
# 4                Ontario         M5V 1E3         Canada  43.643561
# 5                 Quebec         M8Z 5E5         Canada  43.610586
# 6                Ontario         M2J 4W8         Canada  43.769709
# 7                Ontario         M8Z 5E5         Canada  43.610341
# 8                    NaN         M5G 1M1  United States        NaN
# 9               Maryland      20877-4139  United States  39.126883
# 10              New York           10022  United States  40.756638
# 11              New York           10022  United States  40.756638
# 12                   NaN           02110  United States        NaN
# 13            California      94043-1351  United States  37.422000
# 14               Indiana           46204  United States  39.777208
# 15              Illinois      60602-1253  United States  41.883895
# 16            Washington           98104  United States  47.604500
# 17            California           94501  United States  37.766473
# 18      British Columbia             NaN         Canada        NaN
# 19              New York      10013-3170  United States  40.719409
# 20            California      94612-2033  United States  37.806263
# 21                  Utah      84111-4213  United States  40.749425
# 22              New York      10801-6000  United States  40.907486
# 23            California      94103-1734  United States  37.783388
# 24         Massachusetts      02471-9151  United States  42.398829
# 25            Washington      98402-3721  United States  47.256113
# 26            California      94612-1932  United States  37.805320
# 27                Oregon      97201-5840  United States  45.513537
# 28         Massachusetts      02116-3979  United States  42.351486
# 29            California      92008-2634  United States  33.157388
# ..                   ...             ...            ...        ...
# 70               Georgia      30308-1144  United States  33.776958
# 71               Georgia      30308-1144  United States  33.776958
# 72               Georgia      30308-1144  United States  33.776958
# 73               Georgia      30308-1163  United States  33.776958
# 74               Georgia      30308-1163  United States  33.776958
# 75               Georgia      30308-1144  United States  33.776958
# 76               Georgia      30308-1144  United States  33.776958
# 77               Georgia      30308-1148  United States  33.776958
# 78            New Jersey           07068  United States  40.822368
# 79  District of Columbia           20008  United States  38.920256
# 80                   NaN             NaN  United States        NaN
# 81              New York      10583-5339  United States  40.988331
# 82                   NaN             NaN  United States        NaN
# 83              New York      10583-5339  United States  40.988331
# 84                   NaN             NaN  United States        NaN
# 85              New York      10583-5339  United States  40.988331
# 86               Georgia      30308-1144  United States  33.776958
# 87         Massachusetts      02130-2315  United States  42.314556
# 88         Massachusetts      02130-2314  United States  42.314149
# 89         Massachusetts      02130-2314  United States  42.314149
# 90         Massachusetts      02130-2315  United States  42.314556
# 91               Georgia      30308-1144  United States  33.776958
# 92               Georgia      30308-1163  United States  33.776958
# 93               Georgia      30308-1144  United States  33.776958
# 94        North Carolina           28209  United States  35.168512
# 95          Pennsylvania           19312  United States  40.060977
# 96               Georgia      30303-1740  United States  33.759056
# 97               Georgia      30303-1757  United States  33.763064
# 98               Georgia      30339-5683  United States  33.904976
# 99               Georgia      30303-1757  United States  33.763064
#
#            lng                                            address
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3   -77.028155  8601 Georgia Ave Ste 200 Silver Spring Marylan...
# 4   -79.397852        468 Wellington St W Toronto Ontario M5V 1E3
# 5   -79.523320            500 Kipling Ave Montreal Quebec M8Z 5E5
# 6   -79.331981  243 Consumers Rd Phoebe Cres North York Ontari...
# 7   -79.522381          500 Kipling Ave Etobicoke Ontario M8Z 5E5
# 8          NaN                                                NaN
# 9   -77.175667    8652 Dakota Dr Gaithersburg Maryland 20877-4139
# 10  -73.969802       845 3rd Ave. 9th Fl. New York New York 10022
# 11  -73.969802       845 3rd Ave. 9th Fl. New York New York 10022
# 12         NaN                                                NaN
# 13 -122.084058  1600 Amphitheatre Pkwy Google Ventures Mountai...
# 14  -86.160988        132 W Walnut St. Indianapolis Indiana 46204
# 15  -87.632014  121 N La Salle St Rm 1104 Chicago Illinois 606...
# 16 -122.330634  701 5th Avenue Suite 6550 Seattle Washington 9...
# 17 -122.243476     2263 Santa Clara Ave. Alameda California 94501
# 18         NaN                                                NaN
# 19  -74.000036  148 Lafayette St Fl 12 New York New York 10013...
# 20 -122.272418  250 Frank H Ogawa Plz Ste 4314 Oakland Califor...
# 21 -111.887818         110 E 900 S Salt Lake City Utah 84111-4213
# 22  -73.792370       20 Jones St New Rochelle New York 10801-6000
# 23 -122.408013  901 Market St Ste 260 San Francisco California...
# 24  -71.131540        PO BOX 9151 Boston Massachusetts 02471-9151
# 25 -122.441921         747 Market St Tacoma Washington 98402-3721
# 26 -122.272544  1 Frank H Ogawa Plz Oakland California 94612-1932
# 27 -122.676426  111 SW Columbia St Ste 600 Portland Oregon 972...
# 28  -71.066829  10 Park Plz Ste 4160 Boston Massachusetts 0211...
# 29 -117.325792        3951 Park Dr Carlsbad California 92008-2634
# ..         ...                                                ...
# 70  -84.386936  817 W Peachtree St NW Ste 400 Atlanta Georgia ...
# 71  -84.386936  817 W Peachtree St NW Ste 400 Atlanta Georgia ...
# 72  -84.386936  817 W Peachtree St NW Ste 400 Atlanta Georgia ...
# 73  -84.386936  817 W Peachtree St NW Ste a135 Atlanta Georgia...
# 74  -84.386936  817 W Peachtree St NW Ste a135 Atlanta Georgia...
# 75  -84.386936  817 W Peachtree St NW Ste 400 Atlanta Georgia ...
# 76  -84.386936  817 W Peachtree St NW Ste 400 Atlanta Georgia ...
# 77  -84.386936  817 W Peachtree St NW Ste 601 Atlanta Georgia ...
# 78  -74.326395  75 Eisenhower Parkway Suite 180 Roseland New J...
# 79  -77.062925  3100 Massachusetts Ave. NW Washington District...
# 80         NaN                                                NaN
# 81  -73.807076  2 Overhill Rd, Suite 425 Scarsdale, NY 10583 N...
# 82         NaN                                                NaN
# 83  -73.807076  2 Overhill Rd, Suite 425 Scarsdale, NY 10583 N...
# 84         NaN                                                NaN
# 85  -73.807076  2 Overhill Rd, Suite 425 Scarsdale, NY 10583 N...
# 86  -84.386936  817 W Peachtree St NW Ste 400 Atlanta Georgia ...
# 87  -71.102895  30 Germania St Jamaica Plain Massachusetts 021...
# 88  -71.103403  31 Germania St Jamaica Plain Massachusetts 021...
# 89  -71.103403  31 Germania St Jamaica Plain Massachusetts 021...
# 90  -71.102895  30 Germania St Jamaica Plain Massachusetts 021...
# 91  -84.386936  817 W Peachtree St NW Ste 400 Atlanta Georgia ...
# 92  -84.386936  817 W Peachtree St NW Ste a135 Atlanta Georgia...
# 93  -84.386936  817 W Peachtree St NW Ste 400 Atlanta Georgia ...
# 94  -80.849974  4601 Park Rd. Ste. 450 Charlotte North Carolin...
# 95  -75.457707          850 Cassatt Rd. Berwyn Pennsylvania 19312
# 96  -84.387304        191 Peachtree St Atlanta Georgia 30303-1740
# 97  -84.386906  191 Peachtree St NE Ste 3600 Atlanta Georgia 3...
# 98  -84.456596  2500 Windy Ridge Pkwy SE Ste 1600 Atlanta Geor...
# 99  -84.386906  191 Peachtree St NE Ste 3600 Atlanta Georgia 3...
#
# [100 rows x 14 columns]

# %%
print(df2[df2.lat.isnull()==True].shape)
print(df2[df2.lat.isnull()==False].shape)
# Out:
# (6315, 14)
# (10748, 14)

# %% [markdown]
# Many of the address without lats and lngs had faulty coiuntry information; these were corrected manually

# %%
df2 = pd.read_csv('./sianedit_leads_with_distances.csv', encoding = 'ISO-8859-1')

# %%
df2.head()
# Out:
#            Lead ID First Name Last Name    Lead Source Lead Status  \
# 0  00Q1a00000UV8lj         Ed    Thomas  Word of mouth   Qualified
# 1  00Q1a000003MP6x   Victoria    Smythe            NaN   Contacted
# 2  00Q1a00000LqZZE     Manish  Ranpuria    BD Outreach   Contacted
# 3  00Q1a000006GG6R        Ben      Reed            NaN   Qualified
# 4  00Q1a000006Gp2K   Alastair  Ferguson            NaN   Contacted
#
#                        Street       City    State/Province Zip/Postal Code  \
# 0              14 Bedford Sq.     London               NaN        WC1B 3JA
# 1            Castlewood House     London               NaN        WC1A 1DG
# 2  Becket House, 36 Old Jewry     London               NaN         W1W 8RR
# 3         33 Cavendish Square     London               NaN         W1G 0PW
# 4            700 Georgia St W  Vancouver  British Columbia         V7Y 1K8
#
#           Country        lat         lng  \
# 0  United Kingdom        NaN         NaN
# 1  United Kingdom        NaN         NaN
# 2  United Kingdom        NaN         NaN
# 3  United Kingdom        NaN         NaN
# 4          Canada  49.282843 -123.119061
#
#                                              address  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  700 Georgia St W Vancouver British Columbia V7...
#
#                                              addesss
# 0      14 Bedford Sq. London WC1B 3JA United Kingdom
# 1    Castlewood House London WC1A 1DG United Kingdom
# 2  Becket House, 36 Old Jewry London W1W 8RR Unit...
# 3  33 Cavendish Square London W1G 0PW United Kingdom
# 4                                                NaN

# %%
df2.drop(['Unnamed: 0', 'City_1','lat_lng','closest_ts','within_one_tenth','within_one_half','within_one','within_five'], axis=1, inplace=True)

# %%
print(df2[df2.lat.isnull()==True].shape)
print(df2[df2.lat.isnull()==False].shape)
# Out:
# (6055, 13)
# (11005, 13)

# %%
print(df2[df2.address.isnull()==True].shape)
print(df2[df2.address.isnull()==False].shape)
# Out:
# (5443, 13)
# (11617, 13)

# %%
#rebuild address column
df2['address'] = df2['Street']+ ' '+ df2['City'] +' '+ df2['State/Province'] +' '+ df2['Zip/Postal Code']+' '+ df2['Country']

# %%
print(df2[df2.address.isnull()==True].shape)
print(df2[df2.address.isnull()==False].shape)
# Out:
# (5443, 13)
# (11617, 13)

# %%
#df2[df2.address.isnull()==True].head(100)

# %%
print(df2[df2.address.isnull()==True].shape)
print(df2[df2.address.isnull()==False].shape)
# Out:
# (5443, 14)
# (11617, 14)

# %%
print(df2[df2.lat.isnull()==True].shape)
print(df2[df2.lat.isnull()==False].shape)
# Out:
# (6055, 14)
# (11005, 14)

# %%
final_leads = df2[df2.lat.isnull()==False]

# %%
final_leads.to_csv('final_leads.csv',index_label=False)

# %%
#get transitscreen info

# %%
df = pd.read_csv('final_leads.csv')

# %%
df['ts_response'] = np.nan
df['mobility_score'] = np.nan
df['carshare'] = np.nan
df['bikeshare'] = np.nan
df['ridehailing'] = np.nan
df['masstransit'] = np.nan

# %%
df.head()
# Out:
#            Lead ID        First Name Last Name Lead Source Lead Status  \
# 4  00Q1a000006Gp2K          Alastair  Ferguson         NaN   Contacted
# 5  00Q1a00000C2Ubz            Andrea    Janzen         NaN   Contacted
# 6  00Q1a000008DdfH            Daniel     Boffo         NaN   Contacted
# 7  00Q1a000008Ef6q  mbucci@bucci.com     Bucci         NaN   Contacted
# 8  00Q1a00000XhpVs           Michael    Audain         NaN        Open
#
#                   Street       City    State/Province Zip/Postal Code Country  \
# 4       700 Georgia St W  Vancouver  British Columbia         V7Y 1K8  Canada
# 5  10760 Shellbridge Way   Richmond  British Columbia         V6X 3H1  Canada
# 6     1364 Walnut Street  Vancouver  British Columbia         V6J 3R3  Canada
# 7   1669 3rd Ave W W,202   Vancover  British Columbia         V6J 1K1  Canada
# 8    1333 Broadway W 900  Vancouver  British Columbia         V6H 4C2  Canada
#
#          lat         lng                                            address  \
# 4  49.282843 -123.119061  700 Georgia St W Vancouver British Columbia V7...
# 5  49.187104 -123.106134  10760 Shellbridge Way Richmond British Columbi...
# 6  49.273542 -123.148666  1364 Walnut Street Vancouver British Columbia ...
# 7  49.269120 -123.142368  1669 3rd Ave W W,202 Vancover British Columbia...
# 8  49.263873 -123.134263  1333 Broadway W 900 Vancouver British Columbia...
#
#    addesss  ts_response  mobility_score  carshare  bikeshare  ridehailing  \
# 4      NaN          NaN             NaN       NaN        NaN          NaN
# 5      NaN          NaN             NaN       NaN        NaN          NaN
# 6      NaN          NaN             NaN       NaN        NaN          NaN
# 7      NaN          NaN             NaN       NaN        NaN          NaN
# 8      NaN          NaN             NaN       NaN        NaN          NaN
#
#    masstransit
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN

# %%
base_url = 'http://mobilityscore-dev.transitscreen.io/api/v1/locations.json?&debug=true'
key = keys.ts

for i, row in df[(df['ts_response'].isnull()==True)
                 #& (df['id']=='0061a00000GcQdL') #for test
                ].iterrows():
    #print(row.id, row.name, row.lat, row.lng)
    try:
        url = base_url +'&key='+key+'&geojson=true&coordinates='+str(row.lat)+','+str(row.lng)
        #(print(url))
        response = requests.get(url) #wait up to 10 seconds
        data = json.loads(response.text)
        full_response = data['data']
        mobility_score = full_response['mobilityScore']['score']
        #print (mobility_score)
        raw_scores = full_response['mobilityScore']['rawScoreBreakdown']
        #print (raw_scores)
        carshare = raw_scores['carshare']
        bikeshare = raw_scores['bikeshare']
        ridehailing = raw_scores['ridehailing']
        masstransit = raw_scores['masstransit']
        #print(carshare, bikeshare, ridehailing, masstransit)
        df.loc[df['id']==row.id, 'ts_response'] = data
        df.loc[df['id']==row.id, 'mobility_score'] = mobility_score
        df.loc[df['id']==row.id, 'carshare'] = carshare
        df.loc[df['id']==row.id, 'bikeshare'] = bikeshare
        df.loc[df['id']==row.id, 'ridehailing'] = ridehailing
        df.loc[df['id']==row.id, 'masstransit'] = masstransit
    except:
        print('error on', i, raw_scores)
    if i%100 == 0:
        df.to_csv('model_data.csv', index=False)
        print (i, raw_scores)
# Out:
# error on 4 {'carshare': 11.92534484474783, 'bikeshare': 16.949152542372882, 'ridehailing': 13.5, 'masstransit': 156.46584748254372}
# error on 5 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 4.615384615384615, 'masstransit': 12.848971114051395}
# error on 6 {'carshare': 10.582010582010582, 'bikeshare': 12.178619756427604, 'ridehailing': 13.5, 'masstransit': 25.34284460802599}
# error on 7 {'carshare': 8.464613214201739, 'bikeshare': 12.725344644750797, 'ridehailing': 13.5, 'masstransit': 59.764867090417454}
# error on 8 {'carshare': 0, 'bikeshare': 8.72515753756665, 'ridehailing': 13.5, 'masstransit': 79.98483837519224}
# error on 9 {'carshare': 0, 'bikeshare': 8.72515753756665, 'ridehailing': 13.5, 'masstransit': 79.98483837519224}
# error on 10 {'carshare': 0, 'bikeshare': 9.795918367346939, 'ridehailing': 13.5, 'masstransit': 36.79202543395033}
# error on 11 {'carshare': 17.323685705817837, 'bikeshare': 16.728624535315983, 'ridehailing': 13.5, 'masstransit': 49.09466050174922}
# error on 22 {'carshare': 11.354333071021053, 'bikeshare': 19.241047568145376, 'ridehailing': 13.5, 'masstransit': 56.09301193264257}
# error on 23 {'carshare': 0, 'bikeshare': 12.622720897615709, 'ridehailing': 13.5, 'masstransit': 61.574959694275904}
# error on 24 {'carshare': 0, 'bikeshare': 12.622720897615709, 'ridehailing': 13.5, 'masstransit': 61.574959694275904}
# error on 25 {'carshare': 0, 'bikeshare': 11.249999999999998, 'ridehailing': 13.5, 'masstransit': 120.35690884913407}
# error on 26 {'carshare': 13.20170104245724, 'bikeshare': 12.232415902140673, 'ridehailing': 13.5, 'masstransit': 180.63657702864128}
# error on 27 {'carshare': 12.805486848546426, 'bikeshare': 11.166253101736974, 'ridehailing': 13.5, 'masstransit': 112.987801097734}
# error on 28 {'carshare': 15.42496301374806, 'bikeshare': 17.560975609756095, 'ridehailing': 13.5, 'masstransit': 129.53926059996093}
# error on 29 {'carshare': 0, 'bikeshare': 17.408123791102515, 'ridehailing': 13.5, 'masstransit': 57.35353373632121}
# error on 30 {'carshare': 8.851733464470124, 'bikeshare': 11.005808621216755, 'ridehailing': 13.5, 'masstransit': 21.401295209746884}
# error on 31 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 4.615384615384615, 'masstransit': 16.483114973261696}
# error on 32 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 4.615384615384615, 'masstransit': 2.663543841316756}
# error on 33 {'carshare': 2.941276595744681, 'bikeshare': 0, 'ridehailing': 4.615384615384615, 'masstransit': 33.63598381647157}
# error on 35 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 7.5, 'masstransit': 6.094261713177363}
# error on 36 {'carshare': 13.986902540807666, 'bikeshare': 0, 'ridehailing': 7.5, 'masstransit': 49.246576917636}
# error on 37 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 13.5, 'masstransit': 23.208438825123654}
# error on 38 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 7.5, 'masstransit': 33.8453110227845}
# error on 39 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 7.5, 'masstransit': 34.15891903852384}
# error on 40 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 7.5, 'masstransit': 34.15891903852384}
# error on 41 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 7.5, 'masstransit': 34.15891903852384}
# error on 42 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 7.5, 'masstransit': 34.15891903852384}
# error on 43 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 7.5, 'masstransit': 34.15891903852384}
# error on 44 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 7.5, 'masstransit': 34.15891903852384}
# error on 45 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 7.5, 'masstransit': 34.15891903852384}
# error on 46 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 7.5, 'masstransit': 0.4437945719768006}
# error on 47 {'carshare': 12.405237767057201, 'bikeshare': 0, 'ridehailing': 13.5, 'masstransit': 46.18214398580747}
# error on 48 {'carshare': 8.333333333333334, 'bikeshare': 0, 'ridehailing': 13.5, 'masstransit': 70.02202869346986}
# error on 49 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 13.5, 'masstransit': 5.061230355486856}
# error on 50 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 13.5, 'masstransit': 5.061230355486856}
# error on 51 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 13.5, 'masstransit': 5.061230355486856}
# error on 52 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 13.5, 'masstransit': 5.061230355486856}
# error on 53 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 13.5, 'masstransit': 5.061230355486856}
# error on 54 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 13.5, 'masstransit': 5.061230355486856}
# error on 55 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 13.5, 'masstransit': 5.061230355486856}
# error on 56 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 13.5, 'masstransit': 5.061230355486856}
# error on 57 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 13.5, 'masstransit': 5.061230355486856}
# error on 58 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 13.5, 'masstransit': 5.061230355486856}
# error on 59 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 13.5, 'masstransit': 5.061230355486856}
# error on 60 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 13.5, 'masstransit': 5.061230355486856}
# error on 61 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 13.5, 'masstransit': 5.061230355486856}
# error on 62 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 13.5, 'masstransit': 5.061230355486856}
# error on 63 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 7.5, 'masstransit': 0}
# error on 64 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 0, 'masstransit': 0}
# error on 65 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 0, 'masstransit': 0}
# error on 66 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 0, 'masstransit': 0}
# error on 67 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 0, 'masstransit': 0}
# error on 68 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 0, 'masstransit': 0}
# error on 69 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 0, 'masstransit': 0}
# error on 71 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 7.5, 'masstransit': 41.15664307671125}
# error on 72 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 4.615384615384615, 'masstransit': 20.53501361450276}
# error on 73 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 4.615384615384615, 'masstransit': 10.377305186323586}
# error on 74 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 4.615384615384615, 'masstransit': 21.95975786761815}
# error on 75 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 4.615384615384615, 'masstransit': 8.502213515905442}
# error on 76 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 4.615384615384615, 'masstransit': 29.427840059571682}
# error on 77 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 4.615384615384615, 'masstransit': 29.27137265512778}
# error on 78 {'carshare': 3.2359550561797756, 'bikeshare': 0, 'ridehailing': 7.5, 'masstransit': 28.452187787248086}
# error on 79 {'carshare': 9.852216748768473, 'bikeshare': 0, 'ridehailing': 13.5, 'masstransit': 26.887648961037442}
# error on 80 {'carshare': 15.170670037926675, 'bikeshare': 19.108280254777068, 'ridehailing': 13.5, 'masstransit': 66.97955575597291}
# error on 81 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 7.5, 'masstransit': 126.76273429452569}
# error on 82 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 4.615384615384615, 'masstransit': 9.614928545110065}
# error on 83 {'carshare': 4.281201610405698, 'bikeshare': 18.14516129032258, 'ridehailing': 13.5, 'masstransit': 258.8939351506022}
# error on 84 {'carshare': 7.500813890396093, 'bikeshare': 16.885553470919323, 'ridehailing': 13.5, 'masstransit': 278.75890637629357}
# error on 85 {'carshare': 3.7626565051714755, 'bikeshare': 14.90066225165563, 'ridehailing': 13.5, 'masstransit': 87.80749463617634}
# error on 86 {'carshare': 16.000140596304075, 'bikeshare': 15.371477369769428, 'ridehailing': 13.5, 'masstransit': 94.01345986534963}
# error on 87 {'carshare': 0, 'bikeshare': 18.730489073881376, 'ridehailing': 13.5, 'masstransit': 79.74132456839895}
# error on 88 {'carshare': 0, 'bikeshare': 18.730489073881376, 'ridehailing': 13.5, 'masstransit': 79.74132456839895}
# error on 89 {'carshare': 4.048023426061494, 'bikeshare': 13.862148633038121, 'ridehailing': 13.5, 'masstransit': 95.66460543454461}
# error on 90 {'carshare': 0, 'bikeshare': 9.685230024213077, 'ridehailing': 13.5, 'masstransit': 80.69011739081847}
# error on 91 {'carshare': 5.710037174721189, 'bikeshare': 19.543973941368076, 'ridehailing': 13.5, 'masstransit': 84.86602275756749}
# error on 92 {'carshare': 0, 'bikeshare': 18.662519440124417, 'ridehailing': 13.5, 'masstransit': 55.47376872053927}
# error on 93 {'carshare': 0, 'bikeshare': 14.28004760015867, 'ridehailing': 13.5, 'masstransit': 72.87875756729613}
# error on 94 {'carshare': 14.529287859095593, 'bikeshare': 23.825281270681664, 'ridehailing': 13.5, 'masstransit': 74.46560742640328}
# error on 95 {'carshare': 14.529287859095593, 'bikeshare': 23.825281270681664, 'ridehailing': 13.5, 'masstransit': 74.46560742640328}
# error on 96 {'carshare': 11.825500883167273, 'bikeshare': 13.688212927756656, 'ridehailing': 13.5, 'masstransit': 61.78973519392292}
# error on 97 {'carshare': 0, 'bikeshare': 13.468013468013467, 'ridehailing': 13.5, 'masstransit': 48.21419107644066}
# error on 98 {'carshare': 4.88135593220339, 'bikeshare': 17.15102429728442, 'ridehailing': 13.5, 'masstransit': 300.98680655094216}
# error on 99 {'carshare': 4.879632897987999, 'bikeshare': 17.142857142857142, 'ridehailing': 13.5, 'masstransit': 300.06691996374616}
# error on 100 {'carshare': 5.069306930693069, 'bikeshare': 16.90934711131987, 'ridehailing': 13.5, 'masstransit': 272.60283380231056}
# 100 {'carshare': 5.069306930693069, 'bikeshare': 16.90934711131987, 'ridehailing': 13.5, 'masstransit': 272.60283380231056}
# error on 102 {'carshare': 6.783120706575074, 'bikeshare': 18.404907975460123, 'ridehailing': 13.5, 'masstransit': 267.20564783642}
# error on 103 {'carshare': 0, 'bikeshare': 20.327498588368154, 'ridehailing': 13.5, 'masstransit': 352.0990514981971}
# error on 104 {'carshare': 4.192902638762512, 'bikeshare': 16.521340064249657, 'ridehailing': 13.5, 'masstransit': 306.4258690718055}
# error on 105 {'carshare': 0, 'bikeshare': 12.693935119887165, 'ridehailing': 13.5, 'masstransit': 78.44906198809552}
# error on 107 {'carshare': 5.017785843920145, 'bikeshare': 11.468620579802483, 'ridehailing': 13.5, 'masstransit': 276.17583847588446}
# error on 108 {'carshare': 5.529599999999999, 'bikeshare': 12.893982808022923, 'ridehailing': 13.5, 'masstransit': 267.83779494344014}
# error on 109 {'carshare': 6.13854351687389, 'bikeshare': 15.824175824175823, 'ridehailing': 13.5, 'masstransit': 278.44149819363776}
# error on 110 {'carshare': 4.1352078970984145, 'bikeshare': 14.5748987854251, 'ridehailing': 13.5, 'masstransit': 263.06966883541173}
# error on 111 {'carshare': 4.1352078970984145, 'bikeshare': 14.5748987854251, 'ridehailing': 13.5, 'masstransit': 263.06966883541173}
# error on 112 {'carshare': 0, 'bikeshare': 27.252081756245268, 'ridehailing': 13.5, 'masstransit': 96.1603973860091}
# error on 114 {'carshare': 0, 'bikeshare': 27.252081756245268, 'ridehailing': 13.5, 'masstransit': 96.1603973860091}
# error on 116 {'carshare': 10.183693832161108, 'bikeshare': 25.33427163969036, 'ridehailing': 13.5, 'masstransit': 94.58373745614092}
# error on 117 {'carshare': 4.491228070175438, 'bikeshare': 15.037593984962406, 'ridehailing': 13.5, 'masstransit': 262.3663821893755}
# error on 118 {'carshare': 4.491228070175438, 'bikeshare': 15.037593984962406, 'ridehailing': 13.5, 'masstransit': 262.3663821893755}
# error on 119 {'carshare': 0, 'bikeshare': 11.881188118811881, 'ridehailing': 13.5, 'masstransit': 71.69696644377704}
# error on 120 {'carshare': 0, 'bikeshare': 11.881188118811881, 'ridehailing': 13.5, 'masstransit': 71.69696644377704}
# error on 121 {'carshare': 0, 'bikeshare': 11.881188118811881, 'ridehailing': 13.5, 'masstransit': 71.69696644377704}
# error on 122 {'carshare': 4.223648029330889, 'bikeshare': 11.787819253438114, 'ridehailing': 13.5, 'masstransit': 90.93459510522983}
# error on 123 {'carshare': 5.2443095599393015, 'bikeshare': 11.745513866231647, 'ridehailing': 13.5, 'masstransit': 242.69603532365392}
# error on 124 {'carshare': 4.114285714285715, 'bikeshare': 12.636012636012637, 'ridehailing': 13.5, 'masstransit': 266.0065405184141}
# error on 125 {'carshare': 0, 'bikeshare': 13.84083044982699, 'ridehailing': 13.5, 'masstransit': 218.9352521688468}
# error on 126 {'carshare': 0, 'bikeshare': 10.638297872340425, 'ridehailing': 13.5, 'masstransit': 275.70903288873563}
# error on 127 {'carshare': 3.0617940199335547, 'bikeshare': 11.764705882352942, 'ridehailing': 13.5, 'masstransit': 266.1337052070395}
# error on 128 {'carshare': 2.6231499051233396, 'bikeshare': 16.10738255033557, 'ridehailing': 13.5, 'masstransit': 83.17465200810182}
# error on 129 {'carshare': 2.779810979288156, 'bikeshare': 14.551333872271625, 'ridehailing': 13.5, 'masstransit': 67.50542466274965}
# error on 130 {'carshare': 17.301085121728796, 'bikeshare': 10.797840431913617, 'ridehailing': 13.5, 'masstransit': 263.8712238742761}
# error on 131 {'carshare': 17.301085121728796, 'bikeshare': 10.797840431913617, 'ridehailing': 13.5, 'masstransit': 263.8712238742761}
# error on 132 {'carshare': 17.301085121728796, 'bikeshare': 10.797840431913617, 'ridehailing': 13.5, 'masstransit': 263.8712238742761}
# error on 133 {'carshare': 19.060378122694594, 'bikeshare': 12.474012474012472, 'ridehailing': 13.5, 'masstransit': 265.0123395738505}
# error on 134 {'carshare': 0, 'bikeshare': 17.509727626459142, 'ridehailing': 13.5, 'masstransit': 221.4286193826058}
# error on 135 {'carshare': 0, 'bikeshare': 11.414077362079897, 'ridehailing': 13.5, 'masstransit': 208.14350425738988}
# error on 136 {'carshare': 0, 'bikeshare': 13.358070500927642, 'ridehailing': 13.5, 'masstransit': 221.13656209621183}
# error on 137 {'carshare': 17.00752329591594, 'bikeshare': 17.69041769041769, 'ridehailing': 13.5, 'masstransit': 87.54933604251397}
# error on 138 {'carshare': 17.00752329591594, 'bikeshare': 17.69041769041769, 'ridehailing': 13.5, 'masstransit': 87.54933604251397}
# error on 139 {'carshare': 12.923191333072326, 'bikeshare': 13.926499032882012, 'ridehailing': 13.5, 'masstransit': 91.92407400505842}
# error on 140 {'carshare': 0, 'bikeshare': 18.21862348178138, 'ridehailing': 13.5, 'masstransit': 49.554859713221255}
# error on 141 {'carshare': 2.760934691431996, 'bikeshare': 23.856858846918488, 'ridehailing': 13.5, 'masstransit': 51.65528183143677}
# error on 142 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 13.5, 'masstransit': 54.98680647680448}
