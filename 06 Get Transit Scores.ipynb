# %%
import keys
import pandas as pd
import requests
from pprint import pprint
import json
import numpy as np

# %%
df = pd.read_csv('merged_scraped_cleaned.csv')

# %%
df.shape
# Out:
# (1683, 7)

# %%
df.head()
# Out:
#                 id                                            name close_date  \
# 0  0061a00000GcQdL                       525 Water St SW- CMC Mgmt     3/8/18
# 1  0061a00000Mi8dC                    Bozzuto - NJ - Park + Garden    6/30/18
# 2  0061a00000M4PAU                           Greystar- The Cameron   11/17/17
# 3  0061a00000MgelJ                          JLL- 2035 NW Front Ave    1/31/18
# 4  0061a00000KOF8z  International Monetary Fund- Spring Conference    1/31/18
#
#            stage                                            address  \
# 0  Contract Sent  525 Water St SW Washington United States Distr...
# 1   Invoice Sent  1450 Garden St Hoboken United States New Jerse...
# 2    Deal Signed           8710 Cameron St, Silver Spring, MD 20910
# 3  Proposal Sent          1120 NW Couch St #500, Portland, OR 97209
# 4     Closed Won     1900 Pennsylvania Ave NW, Washington, DC 20431
#
#          lat         lng
# 0  38.876059  -77.020240
# 1  40.754448  -74.028046
# 2  38.999289  -77.028885
# 3  45.537557 -122.688094
# 4  38.898940  -77.044101

# %%
#add new columns for Transit Screen API info

# %%
df['ts_response'] = np.nan
df['mobility_score'] = np.nan
df['carshare'] = np.nan
df['bikeshare'] = np.nan
df['ridehailing'] = np.nan
df['masstransit'] = np.nan

# %%
base_url = 'http://mobilityscore-dev.transitscreen.io/api/v1/locations.json?&debug=true'
key = keys.ts

for i, row in df[(df['ts_response'].isnull()==True)
                 #& (df['id']=='0061a00000GcQdL') #for test
                ].iterrows():
    #print(row.id, row.name, row.lat, row.lng)
    try:
        url = base_url +'&key='+key+'&geojson=true&coordinates='+str(row.lat)+','+str(row.lng)
        #(print(url))
        response = requests.get(url) #wait up to 10 seconds
        data = json.loads(response.text)
        full_response = data['data']
        mobility_score = full_response['mobilityScore']['score']
        #print (mobility_score)
        raw_scores = full_response['mobilityScore']['rawScoreBreakdown']
        #print (raw_scores)
        carshare = raw_scores['carshare']
        bikeshare = raw_scores['bikeshare']
        ridehailing = raw_scores['ridehailing']
        masstransit = raw_scores['masstransit']
        #print(carshare, bikeshare, ridehailing, masstransit)
        df.loc[df['id']==row.id, 'ts_response'] = data
        df.loc[df['id']==row.id, 'mobility_score'] = mobility_score
        df.loc[df['id']==row.id, 'carshare'] = carshare
        df.loc[df['id']==row.id, 'bikeshare'] = bikeshare
        df.loc[df['id']==row.id, 'ridehailing'] = ridehailing
        df.loc[df['id']==row.id, 'masstransit'] = masstransit
    except:
        print('error on', i, raw_scores)
    if i%100 == 0:
        df.to_csv('model_data.csv', index=False)
        print (i, raw_scores)
# Out:
# 0 {'carshare': 12.190236663104924, 'bikeshare': 21.71032692317476, 'ridehailing': 21, 'masstransit': 25.347331728747157}
# 100 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 15, 'masstransit': 15.680790004933058}
# 200 {'carshare': 0, 'bikeshare': 36.442392006210916, 'ridehailing': 21, 'masstransit': 111.59136842875225}
# 400 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 0, 'masstransit': 4.543233646460235}
# 800 {'carshare': 4.703640694113644, 'bikeshare': 19.639934533551557, 'ridehailing': 15, 'masstransit': 42.77287604036906}
# 1000 {'carshare': 0, 'bikeshare': 5.960644923715391, 'ridehailing': 15, 'masstransit': 59.23499401064204}
# 1100 {'carshare': 3.3940584335870363, 'bikeshare': 19.58650707290533, 'ridehailing': 13.5, 'masstransit': 163.6700110180089}
# 1300 {'carshare': 0, 'bikeshare': 6.46900269541779, 'ridehailing': 12.115384615384615, 'masstransit': 13.95485619648367}
# 1900 {'carshare': 2.656418139892391, 'bikeshare': 37.49438852852579, 'ridehailing': 21, 'masstransit': 130.1057092559521}
# 2100 {'carshare': 0, 'bikeshare': 0, 'ridehailing': 12.115384615384615, 'masstransit': 0}
# 2300 {'carshare': 4.318650421743206, 'bikeshare': 13.793103448275863, 'ridehailing': 15, 'masstransit': 264.88526249313475}
# 2700 {'carshare': 3.1648351648351647, 'bikeshare': 12.526096033402922, 'ridehailing': 15, 'masstransit': 119.1652291292626}

# %%
df[df.id == '0061a00000GcQdL']
# Out:
#                 id                       name close_date          stage  \
# 0  0061a00000GcQdL  525 Water St SW- CMC Mgmt     3/8/18  Contract Sent
#
#                                              address        lat       lng  \
# 0  525 Water St SW Washington United States Distr...  38.876059 -77.02024
#
#                                          ts_response  mobility_score  \
# 0  {'data': {'mobilityScore': {'latitude': 38.876...            86.0
#
#     carshare  bikeshare  ridehailing  masstransit
# 0  12.190237  21.710327         21.0    25.347332

# %%
df.to_csv('model_data.csv', index=False)

# %%
df.to_csv('model_data_transit_scores_only.csv', index=False)

# %%
df = pd.read_csv('model_data.csv')

# %%
df.head(100)
# Out:
#                  id                                               name  \
# 0   0061a00000GcQdL                          525 Water St SW- CMC Mgmt
# 1   0061a00000Mi8dC                       Bozzuto - NJ - Park + Garden
# 2   0061a00000M4PAU                              Greystar- The Cameron
# 3   0061a00000MgelJ                             JLL- 2035 NW Front Ave
# 4   0061a00000KOF8z     International Monetary Fund- Spring Conference
# 5   0061a00000Mgpep                              GAP HQ- 1 Harrison St
# 6   0061a00000HIaGb                         AVB - AVA Theater - Boston
# 7   0061a00000Mgdqw                    Metro Village- Spring Place- DC
# 8   0061a00000M4P5Q                  Greystar- Aventine at Fort Totten
# 9   0061a00000M3j9z                 Wood Partners- Alta Roosevelt- CHI
# 10  0061a00000M3DjE                Oxford Properties- Royal Bank Plaza
# 11  0061a00000Kkodx  City of Cambridge- 119 Windsor St- Public Heal...
# 12  0061a00000M4fhF                         The Collective- Bedford SQ
# 13  0061a00000MiHRw                     Schupp Comp - Hyatt Place/AUSA
# 14  0061a00000HyrMf                    reThink - Central Florida- FDOT
# 15  0061a00000Irt5y                Daro Management - The Vintage on 16
# 16  0061a00000M3b3g       Concord Hospitality- Hyatt House Jersey City
# 17  0061a00000DJUWm               Seattle Children's Hospital: 12/2017
# 18  0061a00000M6FZM               741 Harvard- Indigo Real Estate- SEA
# 19  0061a00000M5oXh                     Carrolsburg: A Condominium- DC
# 20  0061a00000KkG0w                          Modera Sandy Springs- ATL
# 21  0061a00000KkGL1                     The Horizons- Gates Hudson- VA
# 22  0061a00000KkY0j           Greystar- The Aspen- 1031 4th Street LLC
# 23  0061a00000KkYER                  Donohoe- MD - 7101 Wisconsin Ave.
# 24  0061a00000KkrTg      Transwestern - ATL - 64 Perimeter Center East
# 25  0061a00000KNxoP                         Central Place Office lobby
# 26  0061a00000HI1sq         DTZ-Polk and Taylor Property, LLC- renewal
# 27  0061a00000Kjymq                     GE- 75 Fountain St, Providence
# 28  0061a00000MiJPM                    City of Seattle- Justice Center
# 29  0061a00000IuzTB           MRP - 3101 Wilson HART Hartford Bldg LLC
# ..              ...                                                ...
# 70  0061a00000IsTPK            City of Brookline - Brookline Town Hall
# 71  0061a00000Iuzsa          CBRE / GE - San Ramon - GE Digital Office
# 72  0061a00000Iuztd  CBRE/GE - Cincinnati - GE Global Operations Ce...
# 73  0061a00000IsLBM                     GE - Norwalk - 801 Main Street
# 74  0061a00000Hy4YO               Greystar - Solana Olde Town - Denver
# 75  0061a00000GGPcs  Center for Global Development - DC - 2055 L St...
# 76  0061a00000HvLpd                             Medstar Health - Pilot
# 77  0061a00000ItSOX                           Camden- NoMa DC I and II
# 78  0061a00000Ire2B                         GE- 41 Farnsworth - Boston
# 79  0061a00000JqU7x                      GE- Chicago - 500 W Monroe St
# 80  0061a00000IsDCs  Lincoln Property Company - Chicago - Niche 905...
# 81  0061a00000HEsku   Equity Residential - Courthouse Plaza Apartments
# 82  0061a00000GSDvb                                          Docker SF
# 83  0061a00000GFx46                      GAP-Corporate Headquarters-CA
# 84  0061a00000IuGuU               City of Flagstaff, AZ- City Hall TBD
# 85  0061a00000Mi7W7    Outlook Development Group - Seven 10 West - CHI
# 86  0061a00000OLXPu           The World Bank Group-HQ w/o hotels Pilot
# 87  0061a00000OLQ9V                         JBC - 151 N Franklin - CHI
# 88  0061a00000MhlY6                 Rose Associates - NYC - 88 Leonard
# 89  0061a00000M4tLy                          Greystar- The Grand - DEN
# 90  0061a00000JsKS0                 AREP - 700 E Pratt St / 111 Market
# 91  0061a00000KkQV7  Related Companies - The Arlington - Boston (Ro...
# 92  0061a00000M3OMt                                          Upside-HQ
# 93  0061a00000M2qFA                                      McDonald's HQ
# 94  0061a00000Aab1m                                         The Acadia
# 95  0061a00000MiM7Y                 Rose Associates - NY - Hoyt & Horn
# 96  0061a00000MgMOW                                  Zillow - HQ - NYC
# 97  0061a00000M4Dz7       Crown Property - TOR- 427 and the East Mall,
# 98  0061a00000KNGmq  WinnCompanies - Paul Laurence Dunbar Apartment...
# 99  0061a00000M3kE0  Criterion Development Partners- The Residences...
#
#    close_date             stage  \
# 0      3/8/18     Contract Sent
# 1     6/30/18      Invoice Sent
# 2    11/17/17       Deal Signed
# 3     1/31/18     Proposal Sent
# 4     1/31/18        Closed Won
# 5      2/2/18       Deal Signed
# 6      4/1/17      Invoice Sent
# 7     1/30/18     Proposal Sent
# 8    11/17/17       Deal Signed
# 9    10/27/17        Closed Won
# 10   12/18/17  Contract Expired
# 11    12/7/17       Deal Signed
# 12   11/14/17     Proposal Sent
# 13    2/22/18     Proposal Sent
# 14    2/27/18       Deal Signed
# 15     2/1/18      Presentation
# 16   10/31/17        Closed Won
# 17     1/1/18        Closed Won
# 18     1/9/18        Closed Won
# 19    12/6/17              Lost
# 20    9/26/17              Lost
# 21    9/26/17              Lost
# 22    10/3/17        Closed Won
# 23     3/8/18     Contract Sent
# 24     1/1/18        Closed Won
# 25    9/13/17       Deal Signed
# 26    10/1/17        Closed Won
# 27    11/3/17              Lost
# 28    2/22/18     Proposal Sent
# 29     1/1/18      Presentation
# ..        ...               ...
# 70    5/31/17              Lost
# 71    5/31/17              Lost
# 72    9/29/17     Proposal Sent
# 73    8/31/17              Lost
# 74    3/31/17        Closed Won
# 75   12/30/16      Presentation
# 76    2/28/17              Lost
# 77    5/19/17      Invoice Sent
# 78     3/2/17        Closed Won
# 79    9/29/17     Proposal Sent
# 80    3/15/17      Invoice Sent
# 81    9/29/17              Lost
# 82    3/30/17              Lost
# 83    9/30/16              Lost
# 84    5/31/17              Lost
# 85    3/30/18              Lost
# 86    3/30/18     Contract Sent
# 87     3/8/18       Deal Signed
# 88     3/5/18     Contract Sent
# 89     3/7/18     Contract Sent
# 90   10/31/17              Lost
# 91   11/15/17              Lost
# 92    11/7/17              Lost
# 93    2/16/18       Deal Signed
# 94    8/24/15        Closed Won
# 95    2/26/18       Deal Signed
# 96    2/11/18      Invoice Sent
# 97     3/5/18  Contract Expired
# 98    2/15/18       Deal Signed
# 99   11/17/17       Deal Signed
#
#                                               address        lat         lng  \
# 0   525 Water St SW Washington United States Distr...  38.876059  -77.020240
# 1   1450 Garden St Hoboken United States New Jerse...  40.754448  -74.028046
# 2            8710 Cameron St, Silver Spring, MD 20910  38.999289  -77.028885
# 3           1120 NW Couch St #500, Portland, OR 97209  45.537557 -122.688094
# 4      1900 Pennsylvania Ave NW, Washington, DC 20431  38.898940  -77.044101
# 5              1 Harrison St, San Francisco, CA 94105  37.790608 -122.390911
# 6   45 Stuart Street Boston United States Massachu...  42.351477  -71.063937
# 7   3 Bethesda Metro, Suite 110 Bethesda United St...  38.984468  -77.095870
# 8                5210 3rd St NE, Washington, DC 20011  38.952866  -77.001508
# 9               801 S Financial Pl, Chicago, IL 60605  41.871918  -87.632974
# 10  Royal Bank Plaza North Tower Toronto Canada On...  43.646419  -79.379817
# 11                119 Windsor St, Cambridge, MA 02139  42.369965  -71.103488
# 12  14 Bedford Square, Fitzrovia, London WC1B 3JA, UK  51.519593   -0.130215
# 13  2401 Wilson Blvd Arlington United States Virgi...  38.890877  -77.087370
# 14  250 S Orange Ave\nSuite 200 Orlando United Sta...  28.539621  -81.379354
# 15  2929 Connecticut Ave. NW Suite A Washington Un...  38.929059  -77.054153
# 16               1 Exchange Pl, Jersey City, NJ 07302  40.715749  -74.033918
# 17  4800 Sand Point Way NE Seattle United States W...  47.662638 -122.283265
# 18  741 Harvard Ave E Seattle United States Washin...  47.626283 -122.322696
# 19               1250 4th St SW, Washington, DC 20024  38.875430  -77.017323
# 20                 6125 Roswell Rd, Atlanta, GA 30328  33.922098  -84.378155
# 21            3020 Hamaker Ct #301, Fairfax, VA 22031  38.868260  -77.237192
# 22  1011 4th St NW Washington United States Distri...  38.903440  -77.015986
# 23  7101 Wisconsin Ave Bethesda United States Mary...  38.980403  -77.091756
# 24  64 Perimeter Center East Atlanta United States...  33.920994  -84.331443
# 25  1201 WILSON BLVD. ARLINGTON United States Virg...  38.895359  -77.071184
# 10  {'data': {'mobilityScore': {'latitude': 43.646...           100.0
# 11  {'data': {'mobilityScore': {'latitude': 42.369...            88.0
# 12  {'data': {'mobilityScore': {'latitude': 51.519...           100.0
# 13  {'data': {'mobilityScore': {'latitude': 38.890...            87.0
# 14  {'data': {'mobilityScore': {'latitude': 28.539...            83.0
# 15  {'data': {'mobilityScore': {'latitude': 38.929...            77.0
# 16  {'data': {'mobilityScore': {'latitude': 40.715...            90.0
# 17  {'data': {'mobilityScore': {'latitude': 47.662...           100.0
# 18  {'data': {'mobilityScore': {'latitude': 47.626...            77.0
# 19  {'data': {'mobilityScore': {'latitude': 38.875...            89.0
# 20  {'data': {'mobilityScore': {'latitude': 33.922...            57.0
# 21  {'data': {'mobilityScore': {'latitude': 38.868...            52.0
# 22  {'data': {'mobilityScore': {'latitude': 38.903...            93.0
# 23  {'data': {'mobilityScore': {'latitude': 38.980...           100.0
# 24  {'data': {'mobilityScore': {'latitude': 33.920...            47.0
# 25  {'data': {'mobilityScore': {'latitude': 38.895...            96.0
# 26  {'data': {'mobilityScore': {'latitude': 38.851...            74.0
# 27  {'data': {'mobilityScore': {'latitude': 41.824...            77.0
# 28  {'data': {'mobilityScore': {'latitude': 47.604...           100.0
# 29  {'data': {'mobilityScore': {'latitude': 38.887...            90.0
# ..                                                ...             ...
# 70  {'data': {'mobilityScore': {'latitude': 42.334...            75.0
# 71  {'data': {'mobilityScore': {'latitude': 37.767...            50.0
# 72  {'data': {'mobilityScore': {'latitude': 39.097...           100.0
# 73  {'data': {'mobilityScore': {'latitude': 41.144...            37.0
# 74  {'data': {'mobilityScore': {'latitude': 39.798...            58.0
# 75  {'data': {'mobilityScore': {'latitude': 38.904...           100.0
# 76  {'data': {'mobilityScore': {'latitude': 39.024...            64.0
# 77  {'data': {'mobilityScore': {'latitude': 38.904...            96.0
# 78  {'data': {'mobilityScore': {'latitude': 42.351...            76.0
# 79  {'data': {'mobilityScore': {'latitude': 41.880...           100.0
# 80  {'data': {'mobilityScore': {'latitude': 41.899...            77.0
# 81  {'data': {'mobilityScore': {'latitude': 38.889...            82.0
# 82  {'data': {'mobilityScore': {'latitude': 37.780...            99.0
# 83  {'data': {'mobilityScore': {'latitude': 37.790...           100.0
# 84  {'data': {'mobilityScore': {'latitude': 35.199...            55.0
# 85  {'data': {'mobilityScore': {'latitude': 41.891...            77.0
# 86  {'data': {'mobilityScore': {'latitude': 38.900...           100.0
# 87  {'data': {'mobilityScore': {'latitude': 41.882...           100.0
# 88  {'data': {'mobilityScore': {'latitude': 40.717...           100.0
# 89  {'data': {'mobilityScore': {'latitude': 39.755...           100.0
# 90  {'data': {'mobilityScore': {'latitude': 38.950...            48.0
# 91  {'data': {'mobilityScore': {'latitude': 42.349...           100.0
# 92  {'data': {'mobilityScore': {'latitude': 38.903...           100.0
# 93  {'data': {'mobilityScore': {'latitude': 41.883...            78.0
# 94  {'data': {'mobilityScore': {'latitude': 38.873...            55.0
# 95  {'data': {'mobilityScore': {'latitude': 40.689...           100.0
# 96  {'data': {'mobilityScore': {'latitude': 40.738...           100.0
