# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import sys
import re
import webbrowser
from time import sleep

# %%
# https://stackoverflow.com/questions/4028904/how-to-get-the-home-directory-in-python
from os.path import expanduser
from os import listdir
executable_path = expanduser("~") + "/chromedriver"

if 'chromedriver.exe' not in listdir(expanduser("~")):
    print('chomedriver.exe not found in the home directory! Refer to Selenium docs.')
    sys.exit()

driver = webdriver.Chrome(executable_path=executable_path)
# Out:
# chomedriver.exe not found in the home directory! Refer to Selenium docs.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /Users/rajchakrabarty/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2870: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

import pandas as pd


# https://stackoverflow.com/questions/4028904/how-to-get-the-home-directory-in-python
from os.path import expanduser
from os import listdir
executable_path = expanduser("~") + "/chromedriver"

if 'chromedriver.exe' not in listdir(expanduser("~")):
    print('chomedriver.exe not found in the home directory! Refer to Selenium docs.')
    sys.exit()

driver = webdriver.Chrome(executable_path=executable_path)
# Out:
# chomedriver.exe not found in the home directory! Refer to Selenium docs.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /Users/rajchakrabarty/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2870: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
#opportunities = pd.read_csv('opportunities.csv')
#use this if restarting scraper
opportunities = pd.read_csv('opportunities_scraped.csv')

# %%
opportunities.head()
# Out:
#     Opportunity ID                                   Opportunity Name  \
# 0  0061a00000GFpPA                       Paradigm Properties LLC -TBD
# 1  0061a00000GFwVj             Macklowe Properties - NYC - 1 Wall St.
# 2  0061a00000G3m29                      The Wolff Company - Portfolio
# 3  0061a00000IuoBv                      Paradigm Companies- Portfolio
# 4  0061a00000IuMzU  Pittsburgh Sports & Exhibition Authority - PIT...
#
#   Close Date Created Date Stage Billing Address Line 1 Billing Address Line 2  \
# 0    9/30/16      8/10/16  Lost                    NaN                    NaN
# 1    9/30/16      8/12/16  Lost                    NaN                    NaN
# 2    3/30/17      7/20/16  Lost                    NaN                    NaN
# 3    6/30/17      4/25/17  Lost                    NaN                    NaN
# 4     8/2/17      4/13/17  Lost           171 10th St.                    NaN
#
#   Billing Address Line 3 Mailing Address Line 1 Mailing Address Line 2  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN           200 Ross St.                4th Fl.
#
#   Opp Billing Address Opp Billing Address 2 scraped_address
# 0                 NaN                   NaN       not found
# 1                 NaN                   NaN       not found
# 2                 NaN                   NaN       not found
# 3                 NaN                   NaN       not found
# 4                 NaN                   NaN       not found

# %%
#opportunities['scraped_address']=np.nan

# %%
opportunities[opportunities.scraped_address!='not found'].head()
# Out:
#      Opportunity ID                           Opportunity Name Close Date  \
# 5   0061a00000Iuzsa  CBRE / GE - San Ramon - GE Digital Office    5/31/17
# 7   0061a00000Iut45          Jones Lang LaSalle -  Ireland-TBD    6/30/17
# 14  0061a00000FqbhV                 Philadelphia Airport - PHL   12/31/16
# 16  0061a00000Kjpn0                           Atlassian-Austin    9/30/17
# 18  0061a00000G1jdY                  Discovery - London office    9/23/16
#
#    Created Date       Stage Billing Address Line 1 Billing Address Line 2  \
# 5        5/1/17        Lost                    NaN                    NaN
# 7       4/27/17        Lost                    NaN                    NaN
# 14       6/5/16        Lost                    NaN                    NaN
# 16      9/14/17        Lost      1098 Harrison St.                    NaN
# 18      6/24/16  Closed Won         1 Discovery Pl                    NaN
#
#    Billing Address Line 3              Mailing Address Line 1  \
# 5                     NaN                                 NaN
# 7                     NaN                                 NaN
# 14                    NaN  Philadelphia International Airport
# 16                    NaN                                 NaN
# 18                    NaN                                 NaN
#
#    Mailing Address Line 2 Opp Billing Address Opp Billing Address 2  \
# 5                     NaN                 NaN                   NaN
# 7                     NaN                 NaN                   NaN
# 14             Terminal E                 NaN                   NaN
# 16                    NaN                 NaN                   NaN
# 18                    NaN                 NaN                   NaN
#
#                                       scraped_address
# 5              2623 Camino Ramon, San Ramon, CA 94583
# 7   Styne House, Hatch Street Upper, Saint Kevin's...
# 14         8000 Essington Ave, Philadelphia, PA 19153
# 16            303 Colorado St #1600, Austin, TX 78701
# 18  2, 566 Chiswick High Rd, Chiswick, London W4 5...

# %%
opportunities.head(33)
# Out:
#      Opportunity ID                                   Opportunity Name  \
# 0   0061a00000GFpPA                       Paradigm Properties LLC -TBD
# 1   0061a00000GFwVj             Macklowe Properties - NYC - 1 Wall St.
# 2   0061a00000G3m29                      The Wolff Company - Portfolio
# 3   0061a00000IuoBv                      Paradigm Companies- Portfolio
# 4   0061a00000IuMzU  Pittsburgh Sports & Exhibition Authority - PIT...
# 5   0061a00000Iuzsa          CBRE / GE - San Ramon - GE Digital Office
# 6   0061a00000HyoAr                                   Brookfield - TBD
# 7   0061a00000Iut45                  Jones Lang LaSalle -  Ireland-TBD
# 8   0061a00000HvAWN                 Ottawa Tourism - Wayfinding Ottawa
# 9   0061a00000G55iF                                 Historika - Zurich
# 10  0061a00000Gce3l                        Hanover Company - DEN - TBD
# 11  0061a00000G1Uq3                        Hanover Company - Portfolio
# 12  0061a00000IuO8q                ConAm Group- SEA - Parla Apartments
# 13  0061a00000IuPVh                       The ConAm Group-Location TBD
# 14  0061a00000FqbhV                         Philadelphia Airport - PHL
# 15  0061a00000IuSsn                             Atlassian-Soma Offices
# 16  0061a00000Kjpn0                                   Atlassian-Austin
# 17  0061a00000G1jhu                       Discovery HQ - Silver Spring
# 18  0061a00000G1jdY                          Discovery - London office
# 19  0061a00000G1jdT                             Discovery - NYC office
# 20  0061a00000G1jpA                     Discovery Communications Inc.-
# 21  0061a00000EV5bQ                 Discovery HQ - Silver Spring PILOT
# 22  0061a00000G1bZV                            Discovery - DCTC office
# 23  0061a00000ItjwO                                    Winexburg Manor
# 24  0061a00000Hv5Bq     Monday Properties- 1000-1100 Wilson Owner, LLC
# 25  0061a00000HHUUr        Malibu Investments Inc - 9 Tippet - TORONTO
# 26  0061a00000Mgcmf                 Stream Realty-Navy League Building
# 27  0061a00000Hv1DA                                 EJM Equities - NYC
# 28  0061a00000HxhMR                            LA Clippers Head Office
# 29  0061a00000G53yH                              Engrain - Partnership
# 30  0061a00000MgTWM              Equity Residential - 855 Brannan - SF
# 31  0061a00000MfWGk              Equity Residential - Springline - SEA
# 32  0061a00000G3OhO                       Equity Residential Portfolio
#
#    Close Date Created Date         Stage      Billing Address Line 1  \
# 0     9/30/16      8/10/16          Lost                         NaN
# 1     9/30/16      8/12/16          Lost                         NaN
# 2     3/30/17      7/20/16          Lost                         NaN
# 3     6/30/17      4/25/17          Lost                         NaN
# 4      8/2/17      4/13/17          Lost                171 10th St.
# 5     5/31/17       5/1/17          Lost                         NaN
# 6     5/31/17      2/12/17          Lost                         NaN
# 7     6/30/17      4/27/17          Lost                         NaN
# 8     3/30/17      12/2/16          Lost       1405-150 Elgin Street
# 9     10/3/16       8/1/16  Presentation                         NaN
# 10   10/28/16      9/26/16          Lost                         NaN
# 11    8/31/16      6/21/16          Lost                         NaN
\
# 0                  NaN                   NaN
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN
# 5                  NaN                   NaN
# 6                  NaN                   NaN
# 7                  NaN                   NaN
# 8                  NaN                   NaN
# 9                  NaN                   NaN
# 10                 NaN                   NaN
# 11                 NaN                   NaN
# 12                 NaN                   NaN
# 13                 NaN                   NaN
# 14                 NaN                   NaN
# 15                 NaN                   NaN
# 16                 NaN                   NaN
# 17                 NaN                   NaN
# 18                 NaN                   NaN
# 19                 NaN                   NaN
# 20                 NaN                   NaN
# 21                 NaN                   NaN
# 22                 NaN                   NaN
# 23                 NaN                   NaN
# 24                 NaN                   NaN
# 25                 NaN                   NaN
# 26                 NaN                   NaN
# 27                 NaN                   NaN
# 28                 NaN                   NaN
# 29                 NaN                   NaN
# 30                 NaN                   NaN
# 31                 NaN                   NaN
# 32                 NaN                   NaN
#
#                                       scraped_address
# 0                                           not found
# 1                                           not found
# 2                                           not found
# 3                                           not found
# 4                                           not found
# 5              2623 Camino Ramon, San Ramon, CA 94583
# 6                                           not found
# 7   Styne House, Hatch Street Upper, Saint Kevin's...
# 8                                           not found
# 9                                           not found
# 10                                          not found
# 11                                          not found
# 12                                          not found
# 13                                          not found
# 14         8000 Essington Ave, Philadelphia, PA 19153
# 15                                          not found
# 16            303 Colorado St #1600, Austin, TX 78701
# 17                                          not found
# 18  2, 566 Chiswick High Rd, Chiswick, London W4 5...
# 19             850 3rd Ave # 1003, New York, NY 10022
# 20            1 Discovery Pl, Silver Spring, MD 20910
# 21                                          not found
# 22                                          not found
# 23        2301 Glenallan Ave, Silver Spring, MD 20906
# 24                                          not found
# 25  130 Spadina Ave #707, Toronto, ON M5V 2L4, Canada
# 26     740 15th St NW Suite 200, Washington, DC 20005
# 27       1325 6th Ave Suite #2301, New York, NY 10019
# 28                                          not found
# 29                                          not found
# 30            855 Brannan St, San Francisco, CA 94103
# 31                                          not found
# 32                                          not found

# %%
driver = webdriver.Chrome(executable_path="/Users/rajchakrabarty/Downloads/chromedriver")

# %%
#export to csv
opportunities.to_csv('opportunities_scraped.csv',index_label=False)

# %%
def scrape():
    driver = webdriver.Chrome(executable_path="/Users/rajchakrabarty/Downloads/chromedriver")
    counter = 0
    for i, row in opportunities[(opportunities['scraped_address'].isnull()==True)].iterrows():
        search_term = ''
        url = ''
        address = ''
        search_term = row['Opportunity Name'].replace(' ','+')+'+address'
        url = 'https://www.google.com/search?\&q='+search_term
        driver.get(url)
        search_bar = driver.find_element_by_id('lst-ib')
        search_bar.clear()
        search_bar.send_keys(search_term)
        response = driver.page_source
        html = BeautifulSoup(response, 'lxml')
        span = html.find('span',{'class':'LrzXr'})
        #print (i, search_term)
        try:
            address = span.text
        except:
            address = 'not found'
        #print(address)
        opportunities.loc[opportunities['Opportunity ID'] == row['Opportunity ID']
                          ,'scraped_address'] = address
        counter += 1
        if counter%20 == 0:
            print(i, search_term)
            print(address)
            #sleep(10)

print('start')
keep_going = True
while keep_going:
    try:
        scrape()
        keep_going = False
    except:
        opportunities.to_csv('opportunities_scraped.csv',index_label=False)
    
opportunities.to_csv('opportunities_scraped.csv',index_label=False)
# Out:
# start
# 2344 Palantir+-+Multi+Office+Expansion+address
# 1025 Thomas Jefferson St NW #600, Washington, DC 20007
# 2364 Clear+Channel+UK+address
# not found
# 2402 Mercy+Housing-MSA+address
# not found
# 2422 Macerich+Tysons+Corner+address
# 1961 Chain Bridge Rd, Tysons, VA 22102
# 2460 Concert+Properties-+2+buildings+-+TORONTO+address
# not found
# 2480 Persimmon+Capital-+Huntington+Gardens+address
# not found
